# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Telecom Analytics ETL").getOrCreate()

# %%
# %%writefile customers.csv
# customer_id,customer_name,city,state,age,gender,plan_id,status
# 101,Rahul Sharma,Hyderabad,Telangana,35,Male,P101,Active
# 102,Priya Reddy,Bangalore,Karnataka,29,Female,P102,Active
# 103,Amit Kumar,Mumbai,Maharashtra,42,Male,P103,Inactive
# 104,Sneha Patel,Chennai,Tamil Nadu,31,Female,P101,Active
# 105,Farhan Ali,Delhi,Delhi,55,Male,P104,Active
# 106,Neha Singh,Pune,Maharashtra,38,Female,P102,Active
# 107,Arjun Verma,Hyderabad,Telangana,26,Male,P103,Inactive
# 108,Meera Nair,Kochi,Kerala,48,Female,P104,Active
# 109,Kiran Rao,Bangalore,Karnataka,33,Male,P101,Active
# 110,Nisha Reddy,Delhi,Delhi,41,Female,P102,Active
# 111,Ravi Kumar,Mumbai,Maharashtra,45,Male,P105,Active
# 112,Ayesha Khan,Hyderabad,Telangana,28,Female,,Active
# Out:
# Writing customers.csv

# %%
# %%writefile usage.csv
# usage_id,customer_id,usage_month,data_used_gb,call_minutes,sms_count
# 1001,101,2026-01,45,900,120
# 1002,102,2026-01,30,600,80
# 1003,103,2026-01,12,250,40
# 1004,104,2026-01,55,1100,150
# 1005,105,2026-01,75,1500,200
# 1006,106,2026-01,28,500,60
# 1007,107,2026-01,10,200,20
# 1008,108,2026-01,80,1600,250
# 1009,109,2026-01,48,950,100
# 1010,110,2026-01,32,700,90
# 1011,120,2026-01,60,1300,140
# 1012,101,2026-02,50,1000,130
# 1013,102,2026-02,34,650,85
# 1014,104,2026-02,58,1200,160
# 1015,105,2026-02,,1450,210
# Out:
# Writing usage.csv

# %%
# %%writefile payments.csv
# payment_id,customer_id,bill_month,amount_paid,payment_mode,payment_status
# 5001,101,2026-01,499,UPI,Success
# 5002,102,2026-01,799,Card,Success
# 5003,103,2026-01,299,Cash,Failed
# 5004,104,2026-01,499,UPI,Success
# 5005,105,2026-01,1199,Card,Success
# 5006,106,2026-01,799,UPI,Success
# 5007,107,2026-01,299,Cash,Pending
# 5008,108,2026-01,1199,Card,Success
# 5009,109,2026-01,499,UPI,Success
# 5010,110,2026-01,799,UPI,Success
# 5011,112,2026-01,,UPI,Success
# 5012,101,2026-02,499,Card,Success
# 5013,102,2026-02,799,UPI,Success
# 5014,104,2026-02,499,UPI,Success
# 5015,105,2026-02,1199,,Pending
# Out:
# Writing payments.csv

# %%
# %%writefile plans.json
# [
# {
# "plan_id": "P101",
# "plan_name": "Smart Basic",
# "monthly_fee": 499,
# "data_limit_gb": 50,
# "features": {
# "unlimited_calls": true,
# "ott_included": false,
# "roaming": "National"
# }
# },
# {
# "plan_id": "P102",
# "plan_name": "Smart Plus",
# "monthly_fee": 799,
# "data_limit_gb": 75,
# "features": {
# "unlimited_calls": true,
# "ott_included": true,
# "roaming": "National"
# }
# },
# {
# "plan_id": "P103",
# "plan_name": "Budget Saver",
# "monthly_fee": 299,
# "data_limit_gb": 25,
# "features": {
# "unlimited_calls": false,
# "ott_included": false,
# "roaming": null
# }
# },
# {
# "plan_id": "P104",
# "plan_name": "Premium Max",
# "monthly_fee": 1199,
# "data_limit_gb": 100,
# "features": {
# "unlimited_calls": true,
# "ott_included": true,
# "roaming": "International"
# }
# }
# ]
# Out:
# Writing plans.json

# %%
customers_df = spark.read.csv("customers.csv", header=True,inferSchema=True)
usage_df = spark.read.csv(
    "usage.csv",
    header=True,
    inferSchema=True
)

payments_df = spark.read.csv(
    "payments.csv",
    header=True,
    inferSchema=True
)

plans_df = spark.read.json(
    "plans.json",
    multiLine=True
)

# %%
customers_df.printSchema()
usage_df.printSchema()
payments_df.printSchema()
plans_df.printSchema()
# Out:
# root
#  |-- customer_id: integer (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- plan_id: string (nullable = true)
#  |-- status: string (nullable = true)
#
# root
#  |-- usage_id: integer (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- usage_month: timestamp (nullable = true)
#  |-- data_used_gb: integer (nullable = true)
#  |-- call_minutes: integer (nullable = true)
#  |-- sms_count: integer (nullable = true)
#
# root
#  |-- payment_id: integer (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- bill_month: timestamp (nullable = true)
#  |-- amount_paid: integer (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- payment_status: string (nullable = true)
#
# root
#  |-- data_limit_gb: long (nullable = true)
#  |-- features: struct (nullable = true)
#  |    |-- ott_included: boolean (nullable = true)
#  |    |-- roaming: string (nullable = true)
#  |    |-- unlimited_calls: boolean (nullable = true)
#  |-- monthly_fee: long (nullable = true)
#  |-- plan_id: string (nullable = true)
#  |-- plan_name: string (nullable = true)

# %%
print(customers_df.count())
print(usage_df.count())
print(payments_df.count())
print(plans_df.count())
# Out:
# 12
# 15
# 15
# 4

# %%
customers_df.write.mode("overwrite").parquet("bronze/customers")
usage_df.write.mode("overwrite").parquet("bronze/usage")
payments_df.write.mode("overwrite").parquet("bronze/payments")
plans_df.write.mode("overwrite").parquet("bronze/plans")

# %% [markdown]
# Data Cleaning

# %%
from pyspark.sql.functions import *
customers_df.filter(col("plan_id").isNull()).show()
# Out:
# +-----------+-------------+---------+---------+---+------+-------+------+
# |customer_id|customer_name|     city|    state|age|gender|plan_id|status|
# +-----------+-------------+---------+---------+---+------+-------+------+
# |        112|  Ayesha Khan|Hyderabad|Telangana| 28|Female|   NULL|Active|
# +-----------+-------------+---------+---------+---+------+-------+------+

# %%
usage_df.filter(col("data_used_gb").isNull()).show()
# Out:
# +--------+-----------+-------------------+------------+------------+---------+
# |usage_id|customer_id|        usage_month|data_used_gb|call_minutes|sms_count|
# +--------+-----------+-------------------+------------+------------+---------+
# |    1015|        105|2026-02-01 00:00:00|        NULL|        1450|      210|
# +--------+-----------+-------------------+------------+------------+---------+

# %%
payments_df.filter(col("amount_paid").isNull()).show()
# Out:
# +----------+-----------+-------------------+-----------+------------+--------------+
# |payment_id|customer_id|         bill_month|amount_paid|payment_mode|payment_status|
# +----------+-----------+-------------------+-----------+------------+--------------+
# |      5011|        112|2026-01-01 00:00:00|       NULL|         UPI|       Success|
# +----------+-----------+-------------------+-----------+------------+--------------+

# %%
payments_df.filter(col("payment_mode").isNull()).show()
# Out:
# +----------+-----------+-------------------+-----------+------------+--------------+
# |payment_id|customer_id|         bill_month|amount_paid|payment_mode|payment_status|
# +----------+-----------+-------------------+-----------+------------+--------------+
# |      5015|        105|2026-02-01 00:00:00|       1199|        NULL|       Pending|
# +----------+-----------+-------------------+-----------+------------+--------------+

# %%
customers_cleaned = customers_df.fillna({
    "plan_id":"UNKNOWN"
})

# %%
usage_cleaned = usage_df.fillna({
    "data_used_gb":0
})

payments_cleaned = payments_df.fillna({
    "amount_paid":0,
    "payment_mode":"Not Provided"
})

# %%
customers_cleaned.withColumn("data_quality_status",
                             when(col("plan_id")=="UNKNOWN","Missing Plan").otherwise("Valid"))
# Out:
# DataFrame[customer_id: int, customer_name: string, city: string, state: string, age: int, gender: string, plan_id: string, status: string, data_quality_status: string]

# %%
customers_cleaned = customers_cleaned.withColumn(
    "data_quality_status",
    when(col("plan_id") == "UNKNOWN","Missing Plan")
    .otherwise("Valid")
)


usage_cleaned = usage_cleaned.withColumn(
    "data_quality_status",
    when(col("data_used_gb") == 0,"Missing Usage")
    .otherwise("Valid")
)

payments_cleaned = payments_cleaned.withColumn(
    "data_quality_status",
    when(col("amount_paid") == 0,"Missing Amount")
    .otherwise("Valid")
)

# %%
customers_cleaned.show()
usage_cleaned.show()
payments_cleaned.show()
# Out:
# +-----------+-------------+---------+-----------+---+------+-------+--------+-------------------+
# |customer_id|customer_name|     city|      state|age|gender|plan_id|  status|data_quality_status|
# +-----------+-------------+---------+-----------+---+------+-------+--------+-------------------+
# |        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|   P101|  Active|              Valid|
# |        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|   P102|  Active|              Valid|
# |        103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|   P103|Inactive|              Valid|
# |        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|   P101|  Active|              Valid|
# |        105|   Farhan Ali|    Delhi|      Delhi| 55|  Male|   P104|  Active|              Valid|
# |        106|   Neha Singh|     Pune|Maharashtra| 38|Female|   P102|  Active|              Valid|
# |        107|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|   P103|Inactive|              Valid|
# |        108|   Meera Nair|    Kochi|     Kerala| 48|Female|   P104|  Active|              Valid|
# |        109|    Kiran Rao|Bangalore|  Karnataka| 33|  Male|   P101|  Active|              Valid|
# |        110|  Nisha Reddy|    Delhi|      Delhi| 41|Female|   P102|  Active|              Valid|
# |        111|   Ravi Kumar|   Mumbai|Maharashtra| 45|  Male|   P105|  Active|              Valid|
# |        112|  Ayesha Khan|Hyderabad|  Telangana| 28|Female|UNKNOWN|  Active|       Missing Plan|
# +-----------+-------------+---------+-----------+---+------+-------+--------+-------------------+
#
# +--------+-----------+-------------------+------------+------------+---------+-------------------+
# |usage_id|customer_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|
# +--------+-----------+-------------------+------------+------------+---------+-------------------+
# |    1001|        101|2026-01-01 00:00:00|          45|         900|      120|              Valid|
# |    1002|        102|2026-01-01 00:00:00|          30|         600|       80|              Valid|
# |    1003|        103|2026-01-01 00:00:00|          12|         250|       40|              Valid|
# |    1004|        104|2026-01-01 00:00:00|          55|        1100|      150|              Valid|
# |    1005|        105|2026-01-01 00:00:00|          75|        1500|      200|              Valid|
# |    1006|        106|2026-01-01 00:00:00|          28|         500|       60|              Valid|
# |    1007|        107|2026-01-01 00:00:00|          10|         200|       20|              Valid|
# |    1008|        108|2026-01-01 00:00:00|          80|        1600|      250|              Valid|
# |    1009|        109|2026-01-01 00:00:00|          48|         950|      100|              Valid|
# |    1010|        110|2026-01-01 00:00:00|          32|         700|       90|              Valid|
# |    1011|        120|2026-01-01 00:00:00|          60|        1300|      140|              Valid|
# |    1012|        101|2026-02-01 00:00:00|          50|        1000|      130|              Valid|
# |    1013|        102|2026-02-01 00:00:00|          34|         650|       85|              Valid|
# |    1014|        104|2026-02-01 00:00:00|          58|        1200|      160|              Valid|
# |    1015|        105|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|
# +--------+-----------+-------------------+------------+------------+---------+-------------------+
#
# +----------+-----------+-------------------+-----------+------------+--------------+-------------------+
# |payment_id|customer_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|
# +----------+-----------+-------------------+-----------+------------+--------------+-------------------+
# |      5001|        101|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |      5002|        102|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|
# |      5003|        103|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|
# |      5004|        104|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |      5005|        105|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|
# |      5006|        106|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|
# |      5007|        107|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|
# |      5008|        108|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|
# |      5009|        109|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |      5010|        110|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|
# |      5011|        112|2026-01-01 00:00:00|          0|         UPI|       Success|     Missing Amount|
# |      5012|        101|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|
# |      5013|        102|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|
# |      5014|        104|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|
# |      5015|        105|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|
# +----------+-----------+-------------------+-----------+------------+--------------+-------------------+

# %%
customers_cleaned.write.mode("overwrite").parquet("silver/customers")
usage_cleaned.write.mode("overwrite").parquet("silver/usage")
payments_cleaned.write.mode("overwrite").parquet("silver/payments")

# %%
plans_df.show()
# Out:
# +-------------+--------------------+-----------+-------+------------+
# |data_limit_gb|            features|monthly_fee|plan_id|   plan_name|
# +-------------+--------------------+-----------+-------+------------+
# |           50|{false, National,...|        499|   P101| Smart Basic|
# |           75|{true, National, ...|        799|   P102|  Smart Plus|
# |           25|{false, NULL, false}|        299|   P103|Budget Saver|
# |          100|{true, Internatio...|       1199|   P104| Premium Max|
# +-------------+--------------------+-----------+-------+------------+

# %%
plans_flattened = plans_df.select(
    "plan_id",
    "plan_name",
    "monthly_fee",
    "data_limit_gb",
    col("features.unlimited_calls").alias("unlimited_calls"),
    col("features.ott_included").alias("ott_included"),
    col("features.roaming").alias("roaming")
)

# %%
plans_flattened.show()
# Out:
# +-------+------------+-----------+-------------+---------------+------------+-------------+
# |plan_id|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|
# +-------+------------+-----------+-------------+---------------+------------+-------------+
# |   P101| Smart Basic|        499|           50|           true|       false|     National|
# |   P102|  Smart Plus|        799|           75|           true|        true|     National|
# |   P103|Budget Saver|        299|           25|          false|       false|         NULL|
# |   P104| Premium Max|       1199|          100|           true|        true|International|
# +-------+------------+-----------+-------------+---------------+------------+-------------+

# %%
plans_flattened = plans_flattened.fillna(
    {
        "roaming":"Not Available"
            }
)
plans_flattened.show()
# Out:
# +-------+------------+-----------+-------------+---------------+------------+-------------+
# |plan_id|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|
# +-------+------------+-----------+-------------+---------------+------------+-------------+
# |   P101| Smart Basic|        499|           50|           true|       false|     National|
# |   P102|  Smart Plus|        799|           75|           true|        true|     National|
# |   P103|Budget Saver|        299|           25|          false|       false|Not Available|
# |   P104| Premium Max|       1199|          100|           true|        true|International|
# +-------+------------+-----------+-------------+---------------+------------+-------------+

# %%
plans_flattened.write.mode("overwrite").parquet("silver/plans")

# %%
customer_plan_df = customers_cleaned.join(
    plans_flattened,"plan_id","left"
)
customer_plan_df.show()
# Out:
# +-------+-----------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+
# |plan_id|customer_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|
# +-------+-----------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+
# |   P101|        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|
# |   P102|        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|
# |   P103|        103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|
# |   P101|        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|
# |   P104|        105|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|
# |   P102|        106|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|
# |   P103|        107|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|
# |   P104|        108|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|
# |   P101|        109|    Kiran Rao|Bangalore|  Karnataka| 33|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|
# |   P102|        110|  Nisha Reddy|    Delhi|      Delhi| 41|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|
# |   P105|        111|   Ravi Kumar|   Mumbai|Maharashtra| 45|  Male|  Active|              Valid|        NULL|       NULL|         NULL|           NULL|        NULL|         NULL|
# |UNKNOWN|        112|  Ayesha Khan|Hyderabad|  Telangana| 28|Female|  Active|       Missing Plan|        NULL|       NULL|         NULL|           NULL|        NULL|         NULL|
# +-------+-----------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+

# %%
customer_usage_df = customers_cleaned.join(
    usage_cleaned,
    "customer_id",
    "left"
)
customer_usage_df.show()
# Out:
# +-----------+-------------+---------+-----------+---+------+-------+--------+-------------------+--------+-------------------+------------+------------+---------+-------------------+
# |customer_id|customer_name|     city|      state|age|gender|plan_id|  status|data_quality_status|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|
# +-----------+-------------+---------+-----------+---+------+-------+--------+-------------------+--------+-------------------+------------+------------+---------+-------------------+
# |        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|   P101|  Active|              Valid|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|
# |        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|   P101|  Active|              Valid|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|
# |        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|   P102|  Active|              Valid|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|
# |        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|   P102|  Active|              Valid|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|
# |        103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|   P103|Inactive|              Valid|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|
# |        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|   P101|  Active|              Valid|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|
# |        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|   P101|  Active|              Valid|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|
# |        105|   Farhan Ali|    Delhi|      Delhi| 55|  Male|   P104|  Active|              Valid|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|
# |        105|   Farhan Ali|    Delhi|      Delhi| 55|  Male|   P104|  Active|              Valid|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|
# |        106|   Neha Singh|     Pune|Maharashtra| 38|Female|   P102|  Active|              Valid|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|
# |        107|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|   P103|Inactive|              Valid|    1007|2026-01-01 00:00:00|          10|         200|       20|              Valid|
# |        108|   Meera Nair|    Kochi|     Kerala| 48|Female|   P104|  Active|              Valid|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|
# |        109|    Kiran Rao|Bangalore|  Karnataka| 33|  Male|   P101|  Active|              Valid|    1009|2026-01-01 00:00:00|          48|         950|      100|              Valid|
# |        110|  Nisha Reddy|    Delhi|      Delhi| 41|Female|   P102|  Active|              Valid|    1010|2026-01-01 00:00:00|          32|         700|       90|              Valid|
# |        111|   Ravi Kumar|   Mumbai|Maharashtra| 45|  Male|   P105|  Active|              Valid|    NULL|               NULL|        NULL|        NULL|     NULL|               NULL|
# |        112|  Ayesha Khan|Hyderabad|  Telangana| 28|Female|UNKNOWN|  Active|       Missing Plan|    NULL|               NULL|        NULL|        NULL|     NULL|               NULL|
# +-----------+-------------+---------+-----------+---+------+-------+--------+-------------------+--------+-------------------+------------+------------+---------+-------------------+

# %%
customer_payment_df = customers_cleaned.join(
    payments_cleaned,
    customers_cleaned.customer_id == payments_cleaned.customer_id,
    "left"
)
customer_payment_df.show()
# Out:
# +-----------+-------------+---------+-----------+---+------+-------+--------+-------------------+----------+-----------+-------------------+-----------+------------+--------------+-------------------+
# |customer_id|customer_name|     city|      state|age|gender|plan_id|  status|data_quality_status|payment_id|customer_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|
# +-----------+-------------+---------+-----------+---+------+-------+--------+-------------------+----------+-----------+-------------------+-----------+------------+--------------+-------------------+
# |        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|   P101|  Active|              Valid|      5012|        101|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|
# |        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|   P101|  Active|              Valid|      5001|        101|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|   P102|  Active|              Valid|      5013|        102|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|
# |        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|   P102|  Active|              Valid|      5002|        102|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|
# |        103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|   P103|Inactive|              Valid|      5003|        103|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|
# |        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|   P101|  Active|              Valid|      5014|        104|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|   P101|  Active|              Valid|      5004|        104|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        105|   Farhan Ali|    Delhi|      Delhi| 55|  Male|   P104|  Active|              Valid|      5015|        105|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|
# |        105|   Farhan Ali|    Delhi|      Delhi| 55|  Male|   P104|  Active|              Valid|      5005|        105|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|
# |        106|   Neha Singh|     Pune|Maharashtra| 38|Female|   P102|  Active|              Valid|      5006|        106|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|
# |        107|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|   P103|Inactive|              Valid|      5007|        107|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|
# |        108|   Meera Nair|    Kochi|     Kerala| 48|Female|   P104|  Active|              Valid|      5008|        108|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|
# |        109|    Kiran Rao|Bangalore|  Karnataka| 33|  Male|   P101|  Active|              Valid|      5009|        109|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        110|  Nisha Reddy|    Delhi|      Delhi| 41|Female|   P102|  Active|              Valid|      5010|        110|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|
# |        111|   Ravi Kumar|   Mumbai|Maharashtra| 45|  Male|   P105|  Active|              Valid|      NULL|       NULL|               NULL|       NULL|        NULL|          NULL|               NULL|
# |        112|  Ayesha Khan|Hyderabad|  Telangana| 28|Female|UNKNOWN|  Active|       Missing Plan|      5011|        112|2026-01-01 00:00:00|          0|         UPI|       Success|     Missing Amount|
# +-----------+-------------+---------+-----------+---+------+-------+--------+-------------------+----------+-----------+-------------------+-----------+------------+--------------+-------------------+

# %%
final_df = customers_cleaned \
    .join(plans_flattened,"plan_id","left") \
    .join(usage_cleaned,"customer_id","left") \
    .join(payments_cleaned,"customer_id","left")
final_df.show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|
# |        107|   P103|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1007|2026-01-01 00:00:00|          10|         200|       20|              Valid|      5007|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+
# only showing top 20 rows

# %%
customers_cleaned.join(plans_flattened,"plan_id","left_anti").show()
# Out:
# +-------+-----------+-------------+---------+-----------+---+------+------+-------------------+
# |plan_id|customer_id|customer_name|     city|      state|age|gender|status|data_quality_status|
# +-------+-----------+-------------+---------+-----------+---+------+------+-------------------+
# |   P105|        111|   Ravi Kumar|   Mumbai|Maharashtra| 45|  Male|Active|              Valid|
# |UNKNOWN|        112|  Ayesha Khan|Hyderabad|  Telangana| 28|Female|Active|       Missing Plan|
# +-------+-----------+-------------+---------+-----------+---+------+------+-------------------+

# %%
usage_cleaned.join(
    customers_cleaned,
    "customer_id",
    "left_anti"
).show()
# Out:
# +-----------+--------+-------------------+------------+------------+---------+-------------------+
# |customer_id|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|
# +-----------+--------+-------------------+------------+------------+---------+-------------------+
# |        120|    1011|2026-01-01 00:00:00|          60|        1300|      140|              Valid|
# +-----------+--------+-------------------+------------+------------+---------+-------------------+

# %%
payments_cleaned.join(
    customers_cleaned,
    "customer_id",
    "left_anti"
).show()
# Out:
# +-----------+----------+----------+-----------+------------+--------------+-------------------+
# |customer_id|payment_id|bill_month|amount_paid|payment_mode|payment_status|data_quality_status|
# +-----------+----------+----------+-----------+------------+--------------+-------------------+
# +-----------+----------+----------+-----------+------------+--------------+-------------------+

# %% [markdown]
# Transformations

# %%
final_df = final_df.withColumn(
    "usage_category",
    when(col("data_used_gb") >= 70,"Heavy User")
    .when(col("data_used_gb") >= 30,"Medium User")
    .otherwise("Low User")
)
final_df.show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|      Low User|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|      Low User|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|      Low User|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|      Low User|
# |        107|   P103|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1007|2026-01-01 00:00:00|          10|         200|       20|              Valid|      5007|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|      Low User|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+
# only showing top 20 rows

# %%
final_df = final_df.withColumn(
    "payment_category",
    when(col("amount_paid") >= 1000,"High Payment")
    .when(col("amount_paid") >= 500,"Medium Payment")
    .otherwise("Low Payment")
)
final_df.show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|      Low User|     Low Payment|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|      Low User|    High Payment|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|      Low User|    High Payment|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|      Low User|  Medium Payment|
# |        107|   P103|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1007|2026-01-01 00:00:00|          10|         200|       20|              Valid|      5007|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|      Low User|     Low Payment|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+
# only showing top 20 rows

# %%
final_df = final_df.withColumn(
    "churn_risk",
    when(
        (col("status") == "Inactive") |
        (col("payment_status") != "Success"),
        "High Risk"
    )
    .when(col("data_used_gb") < 15,"Medium Risk")
    .otherwise("Low Risk")
)
final_df.show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category| churn_risk|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|      Low User|     Low Payment|  High Risk|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|      Low User|    High Payment|  High Risk|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|      Low User|    High Payment|Medium Risk|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment|  High Risk|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|      Low User|  Medium Payment|   Low Risk|
# |        107|   P103|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1007|2026-01-01 00:00:00|          10|         200|       20|              Valid|      5007|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|      Low User|     Low Payment|  High Risk|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+
# only showing top 20 rows

# %%
final_df = final_df.withColumn(
    "over_usage_gb",
    col("data_used_gb") - col("data_limit_gb")
)
final_df.show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category| churn_risk|over_usage_gb|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            0|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            0|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|           -5|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|           -5|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -41|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -41|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -45|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -45|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|      Low User|     Low Payment|  High Risk|          -13|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            8|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            8|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            5|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            5|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|      Low User|    High Payment|  High Risk|         -100|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|      Low User|    High Payment|Medium Risk|         -100|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment|  High Risk|          -25|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -25|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|      Low User|  Medium Payment|   Low Risk|          -47|
# |        107|   P103|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1007|2026-01-01 00:00:00|          10|         200|       20|              Valid|      5007|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|      Low User|     Low Payment|  High Risk|          -15|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -20|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+
# only showing top 20 rows

# %%
final_df = final_df.withColumn(
    "over_usage_flag",
    when(col("over_usage_gb") > 0,"Yes")
    .otherwise("No")
)
final_df.show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category| churn_risk|over_usage_gb|over_usage_flag|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            0|             No|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            0|             No|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|           -5|             No|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|           -5|             No|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -41|             No|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -41|             No|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -45|             No|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -45|             No|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|      Low User|     Low Payment|  High Risk|          -13|             No|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            8|            Yes|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            8|            Yes|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            5|            Yes|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            5|            Yes|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|      Low User|    High Payment|  High Risk|         -100|             No|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|      Low User|    High Payment|Medium Risk|         -100|             No|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment|  High Risk|          -25|             No|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -25|             No|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|      Low User|  Medium Payment|   Low Risk|          -47|             No|
# |        107|   P103|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1007|2026-01-01 00:00:00|          10|         200|       20|              Valid|      5007|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|      Low User|     Low Payment|  High Risk|          -15|             No|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -20|             No|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+
# only showing top 20 rows

# %% [markdown]
# Aggregations

# %%
customers_cleaned.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    2|
# |    Kochi|    1|
# |  Chennai|    1|
# |   Mumbai|    2|
# |     Pune|    1|
# |    Delhi|    2|
# |Hyderabad|    3|
# +---------+-----+

# %%
final_df.groupBy("city").sum("amount_paid").show()
# Out:
# +---------+----------------+
# |     city|sum(amount_paid)|
# +---------+----------------+
# |Bangalore|            3695|
# |    Kochi|            1199|
# |  Chennai|            1996|
# |   Mumbai|             299|
# |     Pune|             799|
# |    Delhi|            5595|
# |Hyderabad|            2295|
# +---------+----------------+

# %%
final_df.groupBy("city") \
    .agg(
        sum("amount_paid").alias("total_revenue")
    ) \
    .show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|         3695|
# |    Kochi|         1199|
# |  Chennai|         1996|
# |   Mumbai|          299|
# |     Pune|          799|
# |    Delhi|         5595|
# |Hyderabad|         2295|
# +---------+-------------+

# %%
final_df.groupBy("plan_name") \
    .agg(
        sum("amount_paid").alias("total_revenue")
    ) \
    .show()
# Out:
# +------------+-------------+
# |   plan_name|total_revenue|
# +------------+-------------+
# |        NULL|            0|
# | Smart Basic|         4491|
# |Budget Saver|          598|
# | Premium Max|         5995|
# |  Smart Plus|         4794|
# +------------+-------------+

# %%
final_df.groupBy("plan_name").agg(sum("amount_paid").alias("revenue")).orderBy(col("revenue").desc()).show(1)
# Out:
# +-----------+-------+
# |  plan_name|revenue|
# +-----------+-------+
# |Premium Max|   5995|
# +-----------+-------+
# only showing top 1 row

# %%
final_df.groupBy("usage_category").count().show()
# Out:
# +--------------+-----+
# |usage_category|count|
# +--------------+-----+
# |   Medium User|   14|
# |    Heavy User|    3|
# |      Low User|    7|
# +--------------+-----+

# %%
final_df.groupBy("churn_risk").count().show()
# Out:
# +-----------+-----+
# | churn_risk|count|
# +-----------+-----+
# |   Low Risk|   19|
# |Medium Risk|    1|
# |  High Risk|    4|
# +-----------+-----+

# %%
final_df.groupBy("plan_name").agg( sum("data_used_gb").alias("total_data_usage") ).show()
# Out:
# +------------+----------------+
# |   plan_name|total_data_usage|
# +------------+----------------+
# |        NULL|            NULL|
# | Smart Basic|             464|
# |Budget Saver|              22|
# | Premium Max|             230|
# |  Smart Plus|             188|
# +------------+----------------+

# %%
final_df.groupBy("plan_name").agg( avg("data_used_gb").alias("average_data_usage") ).show()
# Out:
# +------------+------------------+
# |   plan_name|average_data_usage|
# +------------+------------------+
# |        NULL|              NULL|
# | Smart Basic| 51.55555555555556|
# |Budget Saver|              11.0|
# | Premium Max|              46.0|
# |  Smart Plus|31.333333333333332|
# +------------+------------------+

# %%
final_df.groupBy("city").agg( sum("call_minutes").alias("total_call_minutes") ).show()
# Out:
# +---------+------------------+
# |     city|total_call_minutes|
# +---------+------------------+
# |Bangalore|              3450|
# |    Kochi|              1600|
# |  Chennai|              4600|
# |   Mumbai|               250|
# |     Pune|               500|
# |    Delhi|              6600|
# |Hyderabad|              4000|
# +---------+------------------+

# %%
final_df.groupBy("state").agg( sum("sms_count").alias("total_sms") ).show()
# Out:
# +-----------+---------+
# |      state|total_sms|
# +-----------+---------+
# |  Karnataka|      430|
# |     Kerala|      250|
# | Tamil Nadu|      620|
# |      Delhi|      910|
# |  Telangana|      520|
# |Maharashtra|      100|
# +-----------+---------+

# %%
final_df.filter( col("payment_status") == "Success" ).agg( sum("amount_paid").alias("total_successful_revenue") ).show()
# Out:
# +------------------------+
# |total_successful_revenue|
# +------------------------+
# |                   12882|
# +------------------------+

# %%
final_df.groupBy("city").agg( sum("amount_paid").alias("total_revenue") ).show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|         3695|
# |    Kochi|         1199|
# |  Chennai|         1996|
# |   Mumbai|          299|
# |     Pune|          799|
# |    Delhi|         5595|
# |Hyderabad|         2295|
# +---------+-------------+

# %%
final_df.groupBy("plan_name").agg( sum("amount_paid").alias("total_revenue") ).show()
# Out:
# +------------+-------------+
# |   plan_name|total_revenue|
# +------------+-------------+
# |        NULL|            0|
# | Smart Basic|         4491|
# |Budget Saver|          598|
# | Premium Max|         5995|
# |  Smart Plus|         4794|
# +------------+-------------+

# %%
final_df.groupBy("payment_mode").agg( sum("amount_paid").alias("total_revenue") ).show()
# Out:
# +------------+-------------+
# |payment_mode|total_revenue|
# +------------+-------------+
# |        NULL|         NULL|
# |        Card|         6193|
# |        Cash|          598|
# |Not Provided|         2398|
# |         UPI|         6689|
# +------------+-------------+

# %%
final_df.groupBy("city").agg( sum("amount_paid").alias("revenue") ).orderBy(col("revenue").desc()).show(1)
# Out:
# +-----+-------+
# | city|revenue|
# +-----+-------+
# |Delhi|   5595|
# +-----+-------+
# only showing top 1 row

# %% [markdown]
# Window Functions

# %%
from pyspark.sql.window import Window

window_spec = Window.orderBy(col("data_used_gb").desc())

rank_df = final_df.withColumn("data_usage_rank",rank().over(window_spec))

rank_df.show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+---------------+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category|churn_risk|over_usage_gb|over_usage_flag|data_usage_rank|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+---------------+
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|  Low Risk|          -20|             No|              1|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment| High Risk|          -25|             No|              2|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|  Low Risk|          -25|             No|              2|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            8|            Yes|              4|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            8|            Yes|              4|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            5|            Yes|              6|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            5|            Yes|              6|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            0|             No|              8|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            0|             No|              8|
# |        109|   P101|    Kiran Rao|Bangalore|  Karnataka| 33|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1009|2026-01-01 00:00:00|          48|         950|      100|              Valid|      5009|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|           -2|             No|             10|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|           -5|             No|             11|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|           -5|             No|             11|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|  Low Risk|          -41|             No|             13|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|  Low Risk|          -41|             No|             13|
# |        110|   P102|  Nisha Reddy|    Delhi|      Delhi| 41|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1010|2026-01-01 00:00:00|          32|         700|       90|              Valid|      5010|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|  Low Risk|          -43|             No|             15|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|  Low Risk|          -45|             No|             16|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|  Low Risk|          -45|             No|             16|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|      Low User|  Medium Payment|  Low Risk|          -47|             No|             18|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|      Low User|     Low Payment| High Risk|          -13|             No|             19|
# |        107|   P103|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1007|2026-01-01 00:00:00|          10|         200|       20|              Valid|      5007|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|      Low User|     Low Payment| High Risk|          -15|             No|             20|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+---------------+
# only showing top 20 rows

# %%
payment_window = Window.orderBy( col("amount_paid").desc() )
payment_rank_df = final_df.withColumn( "payment_rank", rank().over(payment_window) )
payment_rank_df.show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+------------+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|status|data_quality_status|  plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category| churn_risk|over_usage_gb|over_usage_flag|payment_rank|
# +-----------+-------+-------------+---------+-----------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+------------+
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|      Low User|    High Payment|  High Risk|         -100|             No|           1|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|      Low User|    High Payment|Medium Risk|         -100|             No|           1|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment|  High Risk|          -25|             No|           1|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -25|             No|           1|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -20|             No|           1|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|Active|              Valid| Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -41|             No|           6|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|Active|              Valid| Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -41|             No|           6|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|Active|              Valid| Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -45|             No|           6|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|Active|              Valid| Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -45|             No|           6|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|Active|              Valid| Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|      Low User|  Medium Payment|   Low Risk|          -47|             No|           6|
# |        110|   P102|  Nisha Reddy|    Delhi|      Delhi| 41|Female|Active|              Valid| Smart Plus|        799|           75|           true|        true|     National|    1010|2026-01-01 00:00:00|          32|         700|       90|              Valid|      5010|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -43|             No|           6|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|Active|              Valid|Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            0|             No|          12|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|Active|              Valid|Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            0|             No|          12|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|Active|              Valid|Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|           -5|             No|          12|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|Active|              Valid|Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|           -5|             No|          12|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|Active|              Valid|Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            8|            Yes|          12|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|Active|              Valid|Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            8|            Yes|          12|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|Active|              Valid|Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            5|            Yes|          12|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|Active|              Valid|Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            5|            Yes|          12|
# |        109|   P101|    Kiran Rao|Bangalore|  Karnataka| 33|  Male|Active|              Valid|Smart Basic|        499|           50|           true|       false|     National|    1009|2026-01-01 00:00:00|          48|         950|      100|              Valid|      5009|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|           -2|             No|          12|
# +-----------+-------+-------------+---------+-----------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+------------+
# only showing top 20 rows

# %%
rank_df.filter( col("data_usage_rank") <= 3 ).show()
# Out:
# +-----------+-------+-------------+-----+------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+---------------+
# |customer_id|plan_id|customer_name| city| state|age|gender|status|data_quality_status|  plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category|churn_risk|over_usage_gb|over_usage_flag|data_usage_rank|
# +-----------+-------+-------------+-----+------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+---------------+
# |        108|   P104|   Meera Nair|Kochi|Kerala| 48|Female|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|  Low Risk|          -20|             No|              1|
# |        105|   P104|   Farhan Ali|Delhi| Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment| High Risk|          -25|             No|              2|
# |        105|   P104|   Farhan Ali|Delhi| Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|  Low Risk|          -25|             No|              2|
# +-----------+-------+-------------+-----+------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+---------------+

# %%
payment_rank_df.filter( col("payment_rank") <= 3 ).show()
# Out:
# +-----------+-------+-------------+-----+------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+------------+
# |customer_id|plan_id|customer_name| city| state|age|gender|status|data_quality_status|  plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category| churn_risk|over_usage_gb|over_usage_flag|payment_rank|
# +-----------+-------+-------------+-----+------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+------------+
# |        105|   P104|   Farhan Ali|Delhi| Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|      Low User|    High Payment|  High Risk|         -100|             No|           1|
# |        105|   P104|   Farhan Ali|Delhi| Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|      Low User|    High Payment|Medium Risk|         -100|             No|           1|
# |        105|   P104|   Farhan Ali|Delhi| Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment|  High Risk|          -25|             No|           1|
# |        105|   P104|   Farhan Ali|Delhi| Delhi| 55|  Male|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -25|             No|           1|
# |        108|   P104|   Meera Nair|Kochi|Kerala| 48|Female|Active|              Valid|Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -20|             No|           1|
# +-----------+-------+-------------+-----+------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+------------+

# %%
city_window = Window.partitionBy( "city" ).orderBy(col("data_used_gb").desc())
top_city_df = final_df.withColumn( "rank", row_number().over(city_window) )
top_city_df.filter( col("rank") == 1 ).show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+----+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category|churn_risk|over_usage_gb|over_usage_flag|rank|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+----+
# |        109|   P101|    Kiran Rao|Bangalore|  Karnataka| 33|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1009|2026-01-01 00:00:00|          48|         950|      100|              Valid|      5009|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|           -2|             No|   1|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            8|            Yes|   1|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment| High Risk|          -25|             No|   1|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            0|             No|   1|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|  Low Risk|          -20|             No|   1|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|      Low User|     Low Payment| High Risk|          -13|             No|   1|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|      Low User|  Medium Payment|  Low Risk|          -47|             No|   1|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+----+

# %%
plan_window = Window.partitionBy( "plan_name" ).orderBy(col("data_used_gb").desc())
top_plan_df = final_df.withColumn( "rank", row_number().over(plan_window) )
top_plan_df.filter( col("rank") == 1 ).show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+----+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category|churn_risk|over_usage_gb|over_usage_flag|rank|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+----+
# |        111|   P105|   Ravi Kumar|   Mumbai|Maharashtra| 45|  Male|  Active|              Valid|        NULL|       NULL|         NULL|           NULL|        NULL|         NULL|    NULL|               NULL|        NULL|        NULL|     NULL|               NULL|      NULL|               NULL|       NULL|        NULL|          NULL|               NULL|      Low User|     Low Payment|  Low Risk|         NULL|             No|   1|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|      Low User|     Low Payment| High Risk|          -13|             No|   1|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|  Low Risk|          -20|             No|   1|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            8|            Yes|   1|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|  Low Risk|          -41|             No|   1|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+----+

# %%
revenue_window = Window.orderBy("bill_month")
running_df = final_df.withColumn( "running_total_revenue", sum("amount_paid").over(revenue_window) )
running_df.show()

# %%
customer_window = Window.partitionBy(
    "customer_id"
).orderBy("usage_month")

lag_df = final_df.withColumn(
    "previous_month_usage",
    lag("data_used_gb",1).over(customer_window)
)

lag_df.select("usage_month","data_used_gb","previous_month_usage").show(1000,truncate=False)
# Out:
# +-------------------+------------+--------------------+
# |usage_month        |data_used_gb|previous_month_usage|
# +-------------------+------------+--------------------+
# |2026-01-01 00:00:00|45          |NULL                |
# |2026-01-01 00:00:00|45          |45                  |
# |2026-02-01 00:00:00|50          |45                  |
# |2026-02-01 00:00:00|50          |50                  |
# |2026-01-01 00:00:00|30          |NULL                |
# |2026-01-01 00:00:00|30          |30                  |
# |2026-02-01 00:00:00|34          |30                  |
# |2026-02-01 00:00:00|34          |34                  |
# |2026-01-01 00:00:00|12          |NULL                |
# |2026-01-01 00:00:00|55          |NULL                |
# |2026-01-01 00:00:00|55          |55                  |
# |2026-02-01 00:00:00|58          |55                  |
# |2026-02-01 00:00:00|58          |58                  |
# |2026-01-01 00:00:00|75          |NULL                |
# |2026-01-01 00:00:00|75          |75                  |
# |2026-02-01 00:00:00|0           |75                  |
# |2026-02-01 00:00:00|0           |0                   |
# |2026-01-01 00:00:00|28          |NULL                |
# |2026-01-01 00:00:00|10          |NULL                |
# |2026-01-01 00:00:00|80          |NULL                |
# |2026-01-01 00:00:00|48          |NULL                |
# |2026-01-01 00:00:00|32          |NULL                |
# |NULL               |NULL        |NULL                |
# |NULL               |NULL        |NULL                |
# +-------------------+------------+--------------------+

# %%
lead_df = final_df.withColumn( "next_month_usage", lead("data_used_gb",1).over(customer_window) )
lead_df.show()
# Out:
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+----------------+
# |customer_id|plan_id|customer_name|     city|      state|age|gender|  status|data_quality_status|   plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included|      roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category| churn_risk|over_usage_gb|over_usage_flag|next_month_usage|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+----------------+
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|           -5|             No|              45|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1001|2026-01-01 00:00:00|          45|         900|      120|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|           -5|             No|              50|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            0|             No|              50|
# |        101|   P101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5001|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            0|             No|            NULL|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -45|             No|              30|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1002|2026-01-01 00:00:00|          30|         600|       80|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -45|             No|              34|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -41|             No|              34|
# |        102|   P102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5002|2026-01-01 00:00:00|        799|        Card|       Success|              Valid|   Medium User|  Medium Payment|   Low Risk|          -41|             No|            NULL|
# |        103|   P103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1003|2026-01-01 00:00:00|          12|         250|       40|              Valid|      5003|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|      Low User|     Low Payment|  High Risk|          -13|             No|            NULL|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            5|            Yes|              55|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1004|2026-01-01 00:00:00|          55|        1100|      150|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            5|            Yes|              58|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            8|            Yes|              58|
# |        104|   P101|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|  Active|              Valid| Smart Basic|        499|           50|           true|       false|     National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5004|2026-01-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|   Low Risk|            8|            Yes|            NULL|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|    Heavy User|    High Payment|  High Risk|          -25|             No|              75|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1005|2026-01-01 00:00:00|          75|        1500|      200|              Valid|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -25|             No|               0|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5015|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|      Low User|    High Payment|  High Risk|         -100|             No|               0|
# |        105|   P104|   Farhan Ali|    Delhi|      Delhi| 55|  Male|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1015|2026-02-01 00:00:00|           0|        1450|      210|      Missing Usage|      5005|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|      Low User|    High Payment|Medium Risk|         -100|             No|            NULL|
# |        106|   P102|   Neha Singh|     Pune|Maharashtra| 38|Female|  Active|              Valid|  Smart Plus|        799|           75|           true|        true|     National|    1006|2026-01-01 00:00:00|          28|         500|       60|              Valid|      5006|2026-01-01 00:00:00|        799|         UPI|       Success|              Valid|      Low User|  Medium Payment|   Low Risk|          -47|             No|            NULL|
# |        107|   P103|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|Inactive|              Valid|Budget Saver|        299|           25|          false|       false|Not Available|    1007|2026-01-01 00:00:00|          10|         200|       20|              Valid|      5007|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|      Low User|     Low Payment|  High Risk|          -15|             No|            NULL|
# |        108|   P104|   Meera Nair|    Kochi|     Kerala| 48|Female|  Active|              Valid| Premium Max|       1199|          100|           true|        true|International|    1008|2026-01-01 00:00:00|          80|        1600|      250|              Valid|      5008|2026-01-01 00:00:00|       1199|        Card|       Success|              Valid|    Heavy User|    High Payment|   Low Risk|          -20|             No|            NULL|
# +-----------+-------+-------------+---------+-----------+---+------+--------+-------------------+------------+-----------+-------------+---------------+------------+-------------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+-----------+-------------+---------------+----------------+
# only showing top 20 rows

# %%
lag_df.filter( col("data_used_gb") > col("previous_month_usage") ).show()
# Out:
# +-----------+-------+-------------+---------+----------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+--------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+--------------------+
# |customer_id|plan_id|customer_name|     city|     state|age|gender|status|data_quality_status|  plan_name|monthly_fee|data_limit_gb|unlimited_calls|ott_included| roaming|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|data_quality_status|payment_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|usage_category|payment_category|churn_risk|over_usage_gb|over_usage_flag|previous_month_usage|
# +-----------+-------+-------------+---------+----------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+--------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+--------------------+
# |        101|   P101| Rahul Sharma|Hyderabad| Telangana| 35|  Male|Active|              Valid|Smart Basic|        499|           50|           true|       false|National|    1012|2026-02-01 00:00:00|          50|        1000|      130|              Valid|      5012|2026-02-01 00:00:00|        499|        Card|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            0|             No|                  45|
# |        102|   P102|  Priya Reddy|Bangalore| Karnataka| 29|Female|Active|              Valid| Smart Plus|        799|           75|           true|        true|National|    1013|2026-02-01 00:00:00|          34|         650|       85|              Valid|      5013|2026-02-01 00:00:00|        799|         UPI|       Success|              Valid|   Medium User|  Medium Payment|  Low Risk|          -41|             No|                  30|
# |        104|   P101|  Sneha Patel|  Chennai|Tamil Nadu| 31|Female|Active|              Valid|Smart Basic|        499|           50|           true|       false|National|    1014|2026-02-01 00:00:00|          58|        1200|      160|              Valid|      5014|2026-02-01 00:00:00|        499|         UPI|       Success|              Valid|   Medium User|     Low Payment|  Low Risk|            8|            Yes|                  55|
# +-----------+-------+-------------+---------+----------+---+------+------+-------------------+-----------+-----------+-------------+---------------+------------+--------+--------+-------------------+------------+------------+---------+-------------------+----------+-------------------+-----------+------------+--------------+-------------------+--------------+----------------+----------+-------------+---------------+--------------------+

# %%
customers_cleaned.createOrReplaceTempView("customers")
usage_cleaned.createOrReplaceTempView("usage")
payments_cleaned.createOrReplaceTempView("payments")
plans_flattened.createOrReplaceTempView("plans")
final_df.createOrReplaceTempView("final")

# %%
spark.sql(""" SELECT * FROM customers WHERE status = 'Active' """).show()
# Out:
# +-----------+-------------+---------+-----------+---+------+-------+------+-------------------+
# |customer_id|customer_name|     city|      state|age|gender|plan_id|status|data_quality_status|
# +-----------+-------------+---------+-----------+---+------+-------+------+-------------------+
# |        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|   P101|Active|              Valid|
# |        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|   P102|Active|              Valid|
# |        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|   P101|Active|              Valid|
# |        105|   Farhan Ali|    Delhi|      Delhi| 55|  Male|   P104|Active|              Valid|
# |        106|   Neha Singh|     Pune|Maharashtra| 38|Female|   P102|Active|              Valid|
# |        108|   Meera Nair|    Kochi|     Kerala| 48|Female|   P104|Active|              Valid|
# |        109|    Kiran Rao|Bangalore|  Karnataka| 33|  Male|   P101|Active|              Valid|
# |        110|  Nisha Reddy|    Delhi|      Delhi| 41|Female|   P102|Active|              Valid|
# |        111|   Ravi Kumar|   Mumbai|Maharashtra| 45|  Male|   P105|Active|              Valid|
# |        112|  Ayesha Khan|Hyderabad|  Telangana| 28|Female|UNKNOWN|Active|       Missing Plan|
# +-----------+-------------+---------+-----------+---+------+-------+------+-------------------+

# %%
spark.sql("""SELECT city, count(*) as total_customers FROM customers GROUP BY city""").show()
# Out:
# +---------+---------------+
# |     city|total_customers|
# +---------+---------------+
# |Bangalore|              2|
# |    Kochi|              1|
# |  Chennai|              1|
# |   Mumbai|              2|
# |     Pune|              1|
# |    Delhi|              2|
# |Hyderabad|              3|
# +---------+---------------+

# %%
spark.sql(""" SELECT plan_name, SUM(amount_paid) AS total_revenue FROM final GROUP BY plan_name """).show()
# Out:
# +------------+-------------+
# |   plan_name|total_revenue|
# +------------+-------------+
# |        NULL|            0|
# | Smart Basic|         4491|
# |Budget Saver|          598|
# | Premium Max|         5995|
# |  Smart Plus|         4794|
# +------------+-------------+

# %%
spark.sql(""" SELECT customer_name, data_used_gb FROM final WHERE data_used_gb >= 70 """).show()
# Out:
# +-------------+------------+
# |customer_name|data_used_gb|
# +-------------+------------+
# |   Farhan Ali|          75|
# |   Farhan Ali|          75|
# |   Meera Nair|          80|
# +-------------+------------+

# %%
spark.sql(""" SELECT customer_name, churn_risk FROM final WHERE churn_risk = 'High Risk' """).show()
# Out:
# +-------------+----------+
# |customer_name|churn_risk|
# +-------------+----------+
# |   Amit Kumar| High Risk|
# |   Farhan Ali| High Risk|
# |   Farhan Ali| High Risk|
# |  Arjun Verma| High Risk|
# +-------------+----------+

# %%
spark.sql(""" SELECT * FROM customers WHERE plan_id = 'UNKNOWN' """).show()
# Out:
# +-----------+-------------+---------+---------+---+------+-------+------+-------------------+
# |customer_id|customer_name|     city|    state|age|gender|plan_id|status|data_quality_status|
# +-----------+-------------+---------+---------+---+------+-------+------+-------------------+
# |        112|  Ayesha Khan|Hyderabad|Telangana| 28|Female|UNKNOWN|Active|       Missing Plan|
# +-----------+-------------+---------+---------+---+------+-------+------+-------------------+

# %%
spark.sql(""" SELECT * FROM payments WHERE payment_status IN ('Failed','Pending') """).show()
# Out:
# +----------+-----------+-------------------+-----------+------------+--------------+-------------------+
# |payment_id|customer_id|         bill_month|amount_paid|payment_mode|payment_status|data_quality_status|
# +----------+-----------+-------------------+-----------+------------+--------------+-------------------+
# |      5003|        103|2026-01-01 00:00:00|        299|        Cash|        Failed|              Valid|
# |      5007|        107|2026-01-01 00:00:00|        299|        Cash|       Pending|              Valid|
# |      5015|        105|2026-02-01 00:00:00|       1199|Not Provided|       Pending|              Valid|
# +----------+-----------+-------------------+-----------+------------+--------------+-------------------+

# %%
spark.sql(""" SELECT customer_name, data_used_gb FROM final ORDER BY data_used_gb DESC LIMIT 5 """).show()
# Out:
# +-------------+------------+
# |customer_name|data_used_gb|
# +-------------+------------+
# |   Meera Nair|          80|
# |   Farhan Ali|          75|
# |   Farhan Ali|          75|
# |  Sneha Patel|          58|
# |  Sneha Patel|          58|
# +-------------+------------+

# %%
spark.sql(""" SELECT payment_mode, SUM(amount_paid) AS revenue FROM final GROUP BY payment_mode """).show()
# Out:
# +------------+-------+
# |payment_mode|revenue|
# +------------+-------+
# |        NULL|   NULL|
# |        Card|   6193|
# |        Cash|    598|
# |Not Provided|   2398|
# |         UPI|   6689|
# +------------+-------+

# %%
customers_cleaned = customers_cleaned.withColumnRenamed(
    "data_quality_status",
    "customer_dq_status"
)

usage_cleaned = usage_cleaned.withColumnRenamed(
    "data_quality_status",
    "usage_dq_status"
)

payments_cleaned = payments_cleaned.withColumnRenamed(
    "data_quality_status",
    "payment_dq_status"
)

final_df = customers_cleaned \
    .join(plans_flattened, "plan_id", "left") \
    .join(usage_cleaned, "customer_id", "left") \
    .join(payments_cleaned, "customer_id", "left")

# %%
final_df.write \
    .mode("overwrite") \
    .parquet("gold/customer_analytics")

# %%
final_df.write.mode("overwrite").partitionBy("usage_month").parquet("gold/customer_analytics")

# %%
# %%writefile usage_incremental.csv
# usage_id,customer_id,usage_month,data_used_gb,call_minutes,sms_count
# 1016,101,2026-03,62,1200,150
# 1017,102,2026-03,40,700,95
# 1018,104,2026-03,65,1400,170
# Out:
# Writing usage_incremental.csv

# %%
incremental_df = spark.read.csv( "usage_incremental.csv", header=True, inferSchema=True )

# %%
incremental_df.write.mode("append").parquet("silver/usage")

# %%
updated_usage_df = spark.read.parquet("silver/usage")
customer_usage_summary = customers_cleaned.join( updated_usage_df, "customer_id", "left" )
customer_usage_summary.show()
# Out:
# +-----------+-------------+---------+-----------+---+------+-------+--------+------------------+--------+-------------------+------------+------------+---------+
# |customer_id|customer_name|     city|      state|age|gender|plan_id|  status|customer_dq_status|usage_id|        usage_month|data_used_gb|call_minutes|sms_count|
# +-----------+-------------+---------+-----------+---+------+-------+--------+------------------+--------+-------------------+------------+------------+---------+
# |        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|   P101|  Active|             Valid|    1016|2026-03-01 00:00:00|          62|        1200|      150|
# |        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|   P101|  Active|             Valid|    1012|2026-02-01 00:00:00|          50|        1000|      130|
# |        101| Rahul Sharma|Hyderabad|  Telangana| 35|  Male|   P101|  Active|             Valid|    1001|2026-01-01 00:00:00|          45|         900|      120|
# |        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|   P102|  Active|             Valid|    1017|2026-03-01 00:00:00|          40|         700|       95|
# |        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|   P102|  Active|             Valid|    1013|2026-02-01 00:00:00|          34|         650|       85|
# |        102|  Priya Reddy|Bangalore|  Karnataka| 29|Female|   P102|  Active|             Valid|    1002|2026-01-01 00:00:00|          30|         600|       80|
# |        103|   Amit Kumar|   Mumbai|Maharashtra| 42|  Male|   P103|Inactive|             Valid|    1003|2026-01-01 00:00:00|          12|         250|       40|
# |        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|   P101|  Active|             Valid|    1018|2026-03-01 00:00:00|          65|        1400|      170|
# |        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|   P101|  Active|             Valid|    1014|2026-02-01 00:00:00|          58|        1200|      160|
# |        104|  Sneha Patel|  Chennai| Tamil Nadu| 31|Female|   P101|  Active|             Valid|    1004|2026-01-01 00:00:00|          55|        1100|      150|
# |        105|   Farhan Ali|    Delhi|      Delhi| 55|  Male|   P104|  Active|             Valid|    1015|2026-02-01 00:00:00|           0|        1450|      210|
# |        105|   Farhan Ali|    Delhi|      Delhi| 55|  Male|   P104|  Active|             Valid|    1005|2026-01-01 00:00:00|          75|        1500|      200|
# |        106|   Neha Singh|     Pune|Maharashtra| 38|Female|   P102|  Active|             Valid|    1006|2026-01-01 00:00:00|          28|         500|       60|
# |        107|  Arjun Verma|Hyderabad|  Telangana| 26|  Male|   P103|Inactive|             Valid|    1007|2026-01-01 00:00:00|          10|         200|       20|
# |        108|   Meera Nair|    Kochi|     Kerala| 48|Female|   P104|  Active|             Valid|    1008|2026-01-01 00:00:00|          80|        1600|      250|
# |        109|    Kiran Rao|Bangalore|  Karnataka| 33|  Male|   P101|  Active|             Valid|    1009|2026-01-01 00:00:00|          48|         950|      100|
# |        110|  Nisha Reddy|    Delhi|      Delhi| 41|Female|   P102|  Active|             Valid|    1010|2026-01-01 00:00:00|          32|         700|       90|
# |        111|   Ravi Kumar|   Mumbai|Maharashtra| 45|  Male|   P105|  Active|             Valid|    NULL|               NULL|        NULL|        NULL|     NULL|
# |        112|  Ayesha Khan|Hyderabad|  Telangana| 28|Female|UNKNOWN|  Active|      Missing Plan|    NULL|               NULL|        NULL|        NULL|     NULL|
# +-----------+-------------+---------+-----------+---+------+-------+--------+------------------+--------+-------------------+------------+------------+---------+

# %%
final_df.write \
    .mode("overwrite") \
    .partitionBy("usage_month") \
    .parquet("gold/customer_analytics")

# %%
before_count = usage_cleaned.count()
after_count = spark.read.parquet( "silver/usage" ).count()
print("Before:", before_count)
print("After:", after_count)
# Out:
# Before: 15
# After: 18

# %%
customer_usage_summary = final_df.select( "customer_id", "customer_name", "city", "plan_name", "usage_month", "data_used_gb", "data_limit_gb", "over_usage_flag", "amount_paid", "payment_status", "churn_risk" )
customer_usage_summary.show()
# Out:
# {"ts": "2026-06-13 06:45:02.021", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `over_usage_flag` cannot be resolved. Did you mean one of the following? [`usage_id`, `usage_month`, `age`, `data_used_gb`, `customer_id`]. SQLSTATE: 42703", "context": {"file": "jdk.internal.reflect.GeneratedMethodAccessor78.invoke(Unknown Source)", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o2630.select.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `over_usage_flag` cannot be resolved. Did you mean one of the following? [`usage_id`, `usage_month`, `age`, `data_used_gb`, `customer_id`]. SQLSTATE: 42703;\n'Project [customer_id#17, customer_name#18, city#19, plan_name#75, usage_month#44, data_used_gb#268, data_limit_gb#71L, 'over_usage_flag, amount_paid#269, payment_status#70, 'churn_risk]\n+- Project [customer_id#17, plan_id#267, customer_name#18, city#19, state#20, age#21, gender#22, status#24, customer_dq_status#4029, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, roaming#552, usage_id#42, usage_month#44, data_used_gb#268, call_minutes#46, sms_count#47, usage_dq_status#4030, payment_id#65, bill_month#67, amount_paid#269, payment_mode#270, ... 2 more fields]\n   +- Join LeftOuter, (customer_id#17 = customer_id#66)\n      :- Project [customer_id#17, plan_id#267, customer_name#18, city#19, state#20, age#21, gender#22, status#24, customer_dq_status#4029, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, roaming#552, usage_id#42, usage_month#44, data_used_gb#268, call_minutes#46, sms_count#47, usage_dq_status#4030]\n      :  +- Join LeftOuter, (customer_id#17 = customer_id#43)\n      :     :- Project [plan_id#267, customer_id#17, customer_name#18, city#19, state#20, age#21, gender#22, status#24, customer_dq_status#4029, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, roaming#552]\n      :     :  +- Join LeftOuter, (plan_id#267 = plan_id#74)\n      :     :     :- Project [customer_id#17, customer_name#18, city#19, state#20, age#21, gender#22, plan_id#267, status#24, data_quality_status#371 AS customer_dq_status#4029]\n      :     :     :  +- Project [customer_id#17, customer_name#18, city#19, state#20, age#21, gender#22, plan_id#267, status#24, CASE WHEN (plan_id#267 = UNKNOWN) THEN Missing Plan ELSE Valid END AS data_quality_status#371]\n      :     :     :     +- Project [customer_id#17, customer_name#18, city#19, state#20, age#21, gender#22, coalesce(plan_id#23, cast(UNKNOWN as string)) AS plan_id#267, status#24]\n      :     :     :        +- Relation [customer_id#17,customer_name#18,city#19,state#20,age#21,gender#22,plan_id#23,status#24] csv\n      :     :     +- Project [plan_id#74, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, coalesce(roaming#551, cast(Not Available as string)) AS roaming#552]\n      :     :        +- Project [plan_id#74, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, coalesce(roaming#515, cast(Not Available as string)) AS roaming#551]\n      :     :           +- Project [plan_id#74, plan_name#75, monthly_fee#73L, data_limit_gb#71L, features#72.unlimited_calls AS unlimited_calls#513, features#72.ott_included AS ott_included#514, features#72.roaming AS roaming#515]\n      :     :              +- Relation [data_limit_gb#71L,features#72,monthly_fee#73L,plan_id#74,plan_name#75] json\n      :     +- Project [usage_id#42, customer_id#43, usage_month#44, data_used_gb#268, call_minutes#46, sms_count#47, data_quality_status#372 AS usage_dq_status#4030]\n      :        +- Project [usage_id#42, customer_id#43, usage_month#44,  ...
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipykernel_1987/3596733131.py in <cell line: 0>()
# ----> 1 customer_usage_summary = final_df.select( "customer_id", "customer_name", "city", "plan_name", "usage_month", "data_used_gb", "data_limit_gb", "over_usage_flag", "amount_paid", "payment_status", "churn_risk" )
#       2 customer_usage_summary.show()
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/classic/dataframe.py in select(self, *cols)
#     989
#     990     def select(self, *cols: "ColumnOrName") -> ParentDataFrame:  # type: ignore[misc]
# --> 991         jdf = self._jdf.select(self._jcols(*cols))
#     992         return DataFrame(jdf, self.sparkSession)
#     993
#
# /usr/local/lib/python3.12/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1360
#    1361         answer = self.gateway_client.send_command(command)
# -> 1362         return_value = get_return_value(
#    1363             answer, self.gateway_client, self.target_id, self.name)
#    1364
#
# /usr/local/lib/python3.12/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     286                 # Hide where the exception came from that shows a non-Pythonic
#     287                 # JVM exception message.
# --> 288                 raise converted from None
#     289             else:
#     290                 raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `over_usage_flag` cannot be resolved. Did you mean one of the following? [`usage_id`, `usage_month`, `age`, `data_used_gb`, `customer_id`]. SQLSTATE: 42703;
# 'Project [customer_id#17, customer_name#18, city#19, plan_name#75, usage_month#44, data_used_gb#268, data_limit_gb#71L, 'over_usage_flag, amount_paid#269, payment_status#70, 'churn_risk]
# +- Project [customer_id#17, plan_id#267, customer_name#18, city#19, state#20, age#21, gender#22, status#24, customer_dq_status#4029, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, roaming#552, usage_id#42, usage_month#44, data_used_gb#268, call_minutes#46, sms_count#47, usage_dq_status#4030, payment_id#65, bill_month#67, amount_paid#269, payment_mode#270, ... 2 more fields]
#    +- Join LeftOuter, (customer_id#17 = customer_id#66)
#       :- Project [customer_id#17, plan_id#267, customer_name#18, city#19, state#20, age#21, gender#22, status#24, customer_dq_status#4029, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, roaming#552, usage_id#42, usage_month#44, data_used_gb#268, call_minutes#46, sms_count#47, usage_dq_status#4030]
#       :  +- Join LeftOuter, (customer_id#17 = customer_id#43)
#       :     :- Project [plan_id#267, customer_id#17, customer_name#18, city#19, state#20, age#21, gender#22, status#24, customer_dq_status#4029, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, roaming#552]
#       :     :  +- Join LeftOuter, (plan_id#267 = plan_id#74)
#       :     :     :- Project [customer_id#17, customer_name#18, city#19, state#20, age#21, gender#22, plan_id#267, status#24, data_quality_status#371 AS customer_dq_status#4029]
#       :     :     :  +- Project [customer_id#17, customer_name#18, city#19, state#20, age#21, gender#22, plan_id#267, status#24, CASE WHEN (plan_id#267 = UNKNOWN) THEN Missing Plan ELSE Valid END AS data_quality_status#371]
#       :     :     :     +- Project [customer_id#17, customer_name#18, city#19, state#20, age#21, gender#22, coalesce(plan_id#23, cast(UNKNOWN as string)) AS plan_id#267, status#24]
#       :     :     :        +- Relation [customer_id#17,customer_name#18,city#19,state#20,age#21,gender#22,plan_id#23,status#24] csv
#       :     :     +- Project [plan_id#74, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, coalesce(roaming#551, cast(Not Available as string)) AS roaming#552]
#       :     :        +- Project [plan_id#74, plan_name#75, monthly_fee#73L, data_limit_gb#71L, unlimited_calls#513, ott_included#514, coalesce(roaming#515, cast(Not Available as string)) AS roaming#551]
#       :     :           +- Project [plan_id#74, plan_name#75, monthly_fee#73L, data_limit_gb#71L, features#72.unlimited_calls AS unlimited_calls#513, features#72.ott_included AS ott_included#514, features#72.roaming AS roaming#515]
#       :     :              +- Relation [data_limit_gb#71L,features#72,monthly_fee#73L,plan_id#74,plan_name#75] json
#       :     +- Project [usage_id#42, customer_id#43, usage_month#44, data_used_gb#268, call_minutes#46, sms_count#47, data_quality_status#372 AS usage_dq_status#4030]
#       :        +- Project [usage_id#42, customer_id#43, usage_month#44, data_used_gb#268, call_minutes#46, sms_count#47, CASE WHEN (data_used_gb#268 = 0) THEN Missing Usage ELSE Valid END AS data_quality_status#372]
#       :           +- Project [usage_id#42, customer_id#43, usage_month#44, data_used_gb#268, call_minutes#46, sms_count#47, CASE WHEN (data_used_gb#268 = 0) THEN Missing Usage ELSE Valid END AS data_quality_status#280]
#       :              +- Project [usage_id#42, customer_id#43, usage_month#44, coalesce(data_used_gb#45, cast(0 as int)) AS data_used_gb#268, call_minutes#46, sms_count#47]
#       :                 +- Relation [usage_id#42,customer_id#43,usage_month#44,data_used_gb#45,call_minutes#46,sms_count#47] csv
#       +- Project [payment_id#65, customer_id#66, bill_month#67, amount_paid#269, payment_mode#270, payment_status#70, data_quality_status#373 AS payment_dq_status#4031]
#          +- Project [payment_id#65, customer_id#66, bill_month#67, amount_paid#269, payment_mode#270, payment_status#70, CASE WHEN (amount_paid#269 = 0) THEN Missing Amount ELSE Valid END AS data_quality_status#373]
#             +- Project [payment_id#65, customer_id#66, bill_month#67, amount_paid#269, payment_mode#270, payment_status#70, CASE WHEN (amount_paid#269 = 0) THEN Missing Amount ELSE Valid END AS data_quality_status#281]
#                +- Project [payment_id#65, customer_id#66, bill_month#67, coalesce(amount_paid#68, cast(0 as int)) AS amount_paid#269, coalesce(payment_mode#69, cast(Not Provided as string)) AS payment_mode#270, payment_status#70]
#                   +- Relation [payment_id#65,customer_id#66,bill_month#67,amount_paid#68,payment_mode#69,payment_status#70] csv

# %%
final_df.columns
# Out:
# ['customer_id',
#  'plan_id',
#  'customer_name',
#  'city',
#  'state',
#  'age',
#  'gender',
#  'status',
#  'customer_dq_status',
#  'plan_name',
#  'monthly_fee',
#  'data_limit_gb',
#  'unlimited_calls',
#  'ott_included',
#  'roaming',
#  'usage_id',
#  'usage_month',
#  'data_used_gb',
#  'call_minutes',
#  'sms_count',
#  'usage_dq_status',
#  'payment_id',
#  'bill_month',
#  'amount_paid',
#  'payment_mode',
#  'payment_status',
#  'payment_dq_status']

# %%
from pyspark.sql.functions import *

final_df = final_df.withColumn(
    "usage_category",
    when(col("data_used_gb") >= 70,"Heavy User")
    .when(col("data_used_gb") >= 30,"Medium User")
    .otherwise("Low User")
)
final_df = final_df.withColumn(
    "payment_category",
    when(col("amount_paid") >= 1000,"High Payment")
    .when(col("amount_paid") >= 500,"Medium Payment")
    .otherwise("Low Payment")
)
final_df = final_df.withColumn(
    "churn_risk",
    when(
        (col("status") == "Inactive") |
        (col("payment_status") != "Success"),
        "High Risk"
    )
    .when(col("data_used_gb") < 15,"Medium Risk")
    .otherwise("Low Risk")
)
final_df = final_df.withColumn(
    "over_usage_gb",
    col("data_used_gb") - col("data_limit_gb")
)
final_df = final_df.withColumn(
    "over_usage_flag",
    when(col("over_usage_gb") > 0,"Yes")
    .otherwise("No")
)

# %%
customer_usage_summary = final_df.select(
    "customer_id",
    "customer_name",
    "city",
    "plan_name",
    "usage_month",
    "data_used_gb",
    "data_limit_gb",
    "over_usage_flag",
    "amount_paid",
    "payment_status",
    "churn_risk"
)

customer_usage_summary.show()
# Out:
# +-----------+-------------+---------+------------+-------------------+------------+-------------+---------------+-----------+--------------+-----------+
# |customer_id|customer_name|     city|   plan_name|        usage_month|data_used_gb|data_limit_gb|over_usage_flag|amount_paid|payment_status| churn_risk|
# +-----------+-------------+---------+------------+-------------------+------------+-------------+---------------+-----------+--------------+-----------+
# |        101| Rahul Sharma|Hyderabad| Smart Basic|2026-02-01 00:00:00|          50|           50|             No|        499|       Success|   Low Risk|
# |        101| Rahul Sharma|Hyderabad| Smart Basic|2026-02-01 00:00:00|          50|           50|             No|        499|       Success|   Low Risk|
# |        101| Rahul Sharma|Hyderabad| Smart Basic|2026-01-01 00:00:00|          45|           50|             No|        499|       Success|   Low Risk|
# |        101| Rahul Sharma|Hyderabad| Smart Basic|2026-01-01 00:00:00|          45|           50|             No|        499|       Success|   Low Risk|
# |        102|  Priya Reddy|Bangalore|  Smart Plus|2026-02-01 00:00:00|          34|           75|             No|        799|       Success|   Low Risk|
# |        102|  Priya Reddy|Bangalore|  Smart Plus|2026-02-01 00:00:00|          34|           75|             No|        799|       Success|   Low Risk|
# |        102|  Priya Reddy|Bangalore|  Smart Plus|2026-01-01 00:00:00|          30|           75|             No|        799|       Success|   Low Risk|
# |        102|  Priya Reddy|Bangalore|  Smart Plus|2026-01-01 00:00:00|          30|           75|             No|        799|       Success|   Low Risk|
# |        103|   Amit Kumar|   Mumbai|Budget Saver|2026-01-01 00:00:00|          12|           25|             No|        299|        Failed|  High Risk|
# |        104|  Sneha Patel|  Chennai| Smart Basic|2026-02-01 00:00:00|          58|           50|            Yes|        499|       Success|   Low Risk|
# |        104|  Sneha Patel|  Chennai| Smart Basic|2026-02-01 00:00:00|          58|           50|            Yes|        499|       Success|   Low Risk|
# |        104|  Sneha Patel|  Chennai| Smart Basic|2026-01-01 00:00:00|          55|           50|            Yes|        499|       Success|   Low Risk|
# |        104|  Sneha Patel|  Chennai| Smart Basic|2026-01-01 00:00:00|          55|           50|            Yes|        499|       Success|   Low Risk|
# |        105|   Farhan Ali|    Delhi| Premium Max|2026-02-01 00:00:00|           0|          100|             No|       1199|       Pending|  High Risk|
# |        105|   Farhan Ali|    Delhi| Premium Max|2026-02-01 00:00:00|           0|          100|             No|       1199|       Success|Medium Risk|
# |        105|   Farhan Ali|    Delhi| Premium Max|2026-01-01 00:00:00|          75|          100|             No|       1199|       Pending|  High Risk|
# |        105|   Farhan Ali|    Delhi| Premium Max|2026-01-01 00:00:00|          75|          100|             No|       1199|       Success|   Low Risk|
# |        106|   Neha Singh|     Pune|  Smart Plus|2026-01-01 00:00:00|          28|           75|             No|        799|       Success|   Low Risk|
# |        107|  Arjun Verma|Hyderabad|Budget Saver|2026-01-01 00:00:00|          10|           25|             No|        299|       Pending|  High Risk|
# |        108|   Meera Nair|    Kochi| Premium Max|2026-01-01 00:00:00|          80|          100|             No|       1199|       Success|   Low Risk|
# +-----------+-------------+---------+------------+-------------------+------------+-------------+---------------+-----------+--------------+-----------+
# only showing top 20 rows

# %%
plan_report = final_df.groupBy("plan_name").agg( count_distinct("customer_id").alias("total_customers"), sum("data_used_gb").alias("total_data_usage"), avg("data_used_gb").alias("average_data_usage"), sum("amount_paid").alias("total_revenue") )
plan_report.show()
# Out:
# +------------+---------------+----------------+------------------+-------------+
# |   plan_name|total_customers|total_data_usage|average_data_usage|total_revenue|
# +------------+---------------+----------------+------------------+-------------+
# |        NULL|              2|            NULL|              NULL|            0|
# | Smart Basic|              3|             464| 51.55555555555556|         4491|
# |Budget Saver|              2|              22|              11.0|          598|
# | Premium Max|              2|             230|              46.0|         5995|
# |  Smart Plus|              3|             188|31.333333333333332|         4794|
# +------------+---------------+----------------+------------------+-------------+

# %%
city_report = final_df.groupBy("city").agg( count_distinct("customer_id").alias("total_customers"), sum("amount_paid").alias("total_revenue"), avg("amount_paid").alias("average_payment") )
city_report.show()
# Out:
# +---------+---------------+-------------+---------------+
# |     city|total_customers|total_revenue|average_payment|
# +---------+---------------+-------------+---------------+
# |Bangalore|              2|         3695|          739.0|
# |    Kochi|              1|         1199|         1199.0|
# |  Chennai|              1|         1996|          499.0|
# |   Mumbai|              2|          299|          299.0|
# |     Pune|              1|          799|          799.0|
# |    Delhi|              2|         5595|         1119.0|
# |Hyderabad|              3|         2295|          382.5|
# +---------+---------------+-------------+---------------+

# %%
churn_report = final_df.select( "customer_id", "customer_name", "city", "plan_name", "payment_status", "status", "churn_risk" )
churn_report.show()
# Out:
# +-----------+-------------+---------+------------+--------------+--------+-----------+
# |customer_id|customer_name|     city|   plan_name|payment_status|  status| churn_risk|
# +-----------+-------------+---------+------------+--------------+--------+-----------+
# |        101| Rahul Sharma|Hyderabad| Smart Basic|       Success|  Active|   Low Risk|
# |        101| Rahul Sharma|Hyderabad| Smart Basic|       Success|  Active|   Low Risk|
# |        101| Rahul Sharma|Hyderabad| Smart Basic|       Success|  Active|   Low Risk|
# |        101| Rahul Sharma|Hyderabad| Smart Basic|       Success|  Active|   Low Risk|
# |        102|  Priya Reddy|Bangalore|  Smart Plus|       Success|  Active|   Low Risk|
# |        102|  Priya Reddy|Bangalore|  Smart Plus|       Success|  Active|   Low Risk|
# |        102|  Priya Reddy|Bangalore|  Smart Plus|       Success|  Active|   Low Risk|
# |        102|  Priya Reddy|Bangalore|  Smart Plus|       Success|  Active|   Low Risk|
# |        103|   Amit Kumar|   Mumbai|Budget Saver|        Failed|Inactive|  High Risk|
# |        104|  Sneha Patel|  Chennai| Smart Basic|       Success|  Active|   Low Risk|
# |        104|  Sneha Patel|  Chennai| Smart Basic|       Success|  Active|   Low Risk|
# |        104|  Sneha Patel|  Chennai| Smart Basic|       Success|  Active|   Low Risk|
# |        104|  Sneha Patel|  Chennai| Smart Basic|       Success|  Active|   Low Risk|
# |        105|   Farhan Ali|    Delhi| Premium Max|       Pending|  Active|  High Risk|
# |        105|   Farhan Ali|    Delhi| Premium Max|       Success|  Active|Medium Risk|
# |        105|   Farhan Ali|    Delhi| Premium Max|       Pending|  Active|  High Risk|
# |        105|   Farhan Ali|    Delhi| Premium Max|       Success|  Active|   Low Risk|
# |        106|   Neha Singh|     Pune|  Smart Plus|       Success|  Active|   Low Risk|
# |        107|  Arjun Verma|Hyderabad|Budget Saver|       Pending|Inactive|  High Risk|
# |        108|   Meera Nair|    Kochi| Premium Max|       Success|  Active|   Low Risk|
# +-----------+-------------+---------+------------+--------------+--------+-----------+
# only showing top 20 rows

# %%
over_usage_report = final_df.select( "customer_id", "customer_name", "plan_name", "data_used_gb", "data_limit_gb", "over_usage_gb" )
over_usage_report.show()
# Out:
# +-----------+-------------+------------+------------+-------------+-------------+
# |customer_id|customer_name|   plan_name|data_used_gb|data_limit_gb|over_usage_gb|
# +-----------+-------------+------------+------------+-------------+-------------+
# |        101| Rahul Sharma| Smart Basic|          50|           50|            0|
# |        101| Rahul Sharma| Smart Basic|          50|           50|            0|
# |        101| Rahul Sharma| Smart Basic|          45|           50|           -5|
# |        101| Rahul Sharma| Smart Basic|          45|           50|           -5|
# |        102|  Priya Reddy|  Smart Plus|          34|           75|          -41|
# |        102|  Priya Reddy|  Smart Plus|          34|           75|          -41|
# |        102|  Priya Reddy|  Smart Plus|          30|           75|          -45|
# |        102|  Priya Reddy|  Smart Plus|          30|           75|          -45|
# |        103|   Amit Kumar|Budget Saver|          12|           25|          -13|
# |        104|  Sneha Patel| Smart Basic|          58|           50|            8|
# |        104|  Sneha Patel| Smart Basic|          58|           50|            8|
# |        104|  Sneha Patel| Smart Basic|          55|           50|            5|
# |        104|  Sneha Patel| Smart Basic|          55|           50|            5|
# |        105|   Farhan Ali| Premium Max|           0|          100|         -100|
# |        105|   Farhan Ali| Premium Max|           0|          100|         -100|
# |        105|   Farhan Ali| Premium Max|          75|          100|          -25|
# |        105|   Farhan Ali| Premium Max|          75|          100|          -25|
# |        106|   Neha Singh|  Smart Plus|          28|           75|          -47|
# |        107|  Arjun Verma|Budget Saver|          10|           25|          -15|
# |        108|   Meera Nair| Premium Max|          80|          100|          -20|
# +-----------+-------------+------------+------------+-------------+-------------+
# only showing top 20 rows
